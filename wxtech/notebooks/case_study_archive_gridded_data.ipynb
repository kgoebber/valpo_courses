# %%
from datetime import datetime

import xarray as xr

# %% [markdown]
# ## GFS 0.5 Degree Data
#
# Data from December 2007 - nearly present

# %%
date = datetime(2007, 12, 25, 0)

# GFS 0.5 degree Analysis back to 06 UTC 24 December 2007 to five days prior to present
ds = xr.open_dataset('https://www.ncei.noaa.gov/thredds/dodsC/model-gfs-g4-anl-files-old/'
                     f'{date:%Y%m/%Y%m%d}/gfsanl_4_{date:%Y%m%d_%H}00_000.grb2')
ds

# %% [markdown]
# ## GFS 1 Degree Data
#
# Data from March 2004 - nearly present

# %%
date = datetime(2004, 3, 2, 0)

# GFS 1 degree Analysis back to 00 UTC 2 March 2004 to five days prior to present
ds = xr.open_dataset('https://www.ncei.noaa.gov/thredds/dodsC/model-gfs-g3-anl-files-old/'
                     f'{date:%Y%m/%Y%m%d}/gfsanl_3_{date:%Y%m%d_%H}00_000.grb')
ds

# %% [markdown]
# ## NAM 12 km Data
#
# Data from March 2004 - nearly present

# %%
date = datetime(2004, 3, 2, 18)

# NAM 218 Grid Analysis back to 18 UTC 2 March 2004 to five days prior to present
ds = xr.open_dataset('https://www.ncei.noaa.gov/thredds/dodsC/model-namanl-old/'
                     f'{date:%Y%m/%Y%m%d}/namanl_218_{date:%Y%m%d_%H}00_000.grb')
ds

# %% [markdown]
# ## North American Regional Reanalysis
# Data from January 1979 - September 2014

# %%
date = datetime(1979, 1, 1, 0)

# North American Regional Reanalysis Analysis back to 0 UTC 1 January 1979 to 30 September 2014
ds = xr.open_dataset('https://www.ncei.noaa.gov/thredds/dodsC/model-narr-a-files/'
                     f'{date:%Y%m/%Y%m%d}/narr-a_221_{date:%Y%m%d_%H}00_000.grb')
ds

# %% [markdown]
# ## RDA GFS Analysis Archive
#
# Data from 6 December 2007 - 3 December 2020

# %%
from siphon.catalog import TDSCatalog

catUrl = "https://rda.ucar.edu/thredds/catalog/aggregations/g/ds083.2/2/catalog.xml"
datasetName = "Full Collection Dataset"
catalog = TDSCatalog(catUrl)
dataset = catalog.datasets[datasetName]
ds = dataset.remote_access(use_xarray=True)

ds
# Out:
# <xarray.Dataset>
# Dimensions:                                                                   (: 2, altitude_above_msl: 6, altitude_above_msl1: 1, depth_below_surface_layer: 4, height_above_ground: 1, height_above_ground1: 7, height_above_ground2: 1, height_above_ground3: 2, height_above_ground4: 3, height_above_ground_layer: 1, height_above_ground_layer1: 1, hybrid: 1, isobaric: 34, isobaric1: 2, isobaric2: 24, isobaric3: 1, isobaric4: 29, isobaric5: 21, isobaric6: 31, isobaric7: 22, lat: 181, lon: 360, potential_vorticity_surface: 2, pressure_difference_layer: 1, pressure_difference_layer1: 1, pressure_difference_layer2: 2, sigma: 1, sigma_layer: 4, time: 7423, time1: 4340, time2: 1568, time3: 8600, time4: 10380, time5: 18983, time6: 18980, time7: 2159, time8: 10383)
# Coordinates:
#   * lat                                                                       (lat) float32 ...
#   * lon                                                                       (lon) float32 ...
#   * time                                                                      (time) datetime64[ns] ...
#     reftime                                                                   (time) datetime64[ns] ...
#   * time1                                                                     (time1) datetime64[ns] ...
#     reftime1                                                                  (time1) datetime64[ns] ...
#   * time2                                                                     (time2) datetime64[ns] ...
#     reftime2                                                                  (time2) datetime64[ns] ...
#   * time3                                                                     (time3) datetime64[ns] ...
#     reftime3                                                                  (time3) datetime64[ns] ...
#   * time4                                                                     (time4) datetime64[ns] ...
#     reftime4                                                                  (time4) datetime64[ns] ...
#   * time5                                                                     (time5) datetime64[ns] ...
#     reftime5                                                                  (time5) datetime64[ns] ...
#   * time6                                                                     (time6) datetime64[ns] ...
#     reftime6                                                                  (time6) datetime64[ns] ...
#   * time7                                                                     (time7) datetime64[ns] ...
#     reftime7                                                                  (time7) datetime64[ns] ...
#   * time8                                                                     (time8) datetime64[ns] ...
#     reftime8                                                                  (time8) datetime64[ns] ...
#   * potential_vorticity_surface                                               (potential_vorticity_surface) float32 ...
#   * height_above_ground                                                       (height_above_ground) float32 ...
#   * isobaric                                                                  (isobaric) float32 ...
#   * isobaric1                                                                 (isobaric1) float32 ...
#   * height_above_ground1                                                      (height_above_ground1) float32 ...
#   * height_above_ground_layer                                                 (height_above_ground_layer) float32 ...
#   * height_above_ground2                                                      (height_above_ground2) float32 ...
#   * isobaric2                                                                 (isobaric2) float32 ...
#   * altitude_above_msl                                                        (altitude_above_msl) float32 ...
#   * isobaric3                                                                 (isobaric3) float32 ...
#   * pressure_difference_layer                                                 (pressure_difference_layer) float32 ...
#   * depth_below_surface_layer                                                 (depth_below_surface_layer) float32 ...
#   * height_above_ground_layer1                                                (height_above_ground_layer1) float32 ...
#   * hybrid                                                                    (hybrid) float32 ...
#   * isobaric4                                                                 (isobaric4) float32 ...
#   * height_above_ground3                                                      (height_above_ground3) float32 ...
#   * pressure_difference_layer1                                                (pressure_difference_layer1) float32 ...
#   * isobaric5                                                                 (isobaric5) float32 ...
#   * sigma                                                                     (sigma) float32 ...
#   * isobaric6                                                                 (isobaric6) float32 ...
#   * isobaric7                                                                 (isobaric7) float32 ...
#   * sigma_layer                                                               (sigma_layer) float32 ...
#   * height_above_ground4                                                      (height_above_ground4) float32 ...
#   * pressure_difference_layer2                                                (pressure_difference_layer2) float32 ...
#   * altitude_above_msl1                                                       (altitude_above_msl1) float32 ...
# Dimensions without coordinates:
# Data variables:
#     LatLon_Projection                                                         int32 ...
#     height_above_ground_layer_bounds                                          (height_above_ground_layer, ) float32 ...
#     pressure_difference_layer_bounds                                          (pressure_difference_layer, ) float32 ...
#     depth_below_surface_layer_bounds                                          (depth_below_surface_layer, ) float32 ...
#     height_above_ground_layer1_bounds                                         (height_above_ground_layer1, ) float32 ...
#     pressure_difference_layer1_bounds                                         (pressure_difference_layer1, ) float32 ...
#     sigma_layer_bounds                                                        (sigma_layer, ) float32 ...
#     pressure_difference_layer2_bounds                                         (pressure_difference_layer2, ) float32 ...
#     Total_ozone_entire_atmosphere_single_layer                                (time5, lat, lon) float32 ...
#     Ozone_Mixing_Ratio_isobaric                                               (time5, isobaric2, lat, lon) float32 ...
#     Surface_Lifted_Index_surface                                              (time5, lat, lon) float32 ...
#     Vertical_Speed_Shear_potential_vorticity_surface                          (time5, potential_vorticity_surface, lat, lon) float32 ...
#     Vertical_Speed_Shear_tropopause                                           (time5, lat, lon) float32 ...
#     Ventilation_Rate_planetary_boundary                                       (time3, lat, lon) float32 ...
#     MSLP_Eta_model_reduction_msl                                              (time3, lat, lon) float32 ...
#     Pressure_of_level_from_which_parcel_was_lifted_pressure_difference_layer  (time3, pressure_difference_layer, lat, lon) float32 ...
#     Wind_speed_gust_surface                                                   (time3, lat, lon) float32 ...
#     Volumetric_Soil_Moisture_Content_depth_below_surface_layer                (time5, depth_below_surface_layer, lat, lon) float32 ...
#     Potential_Evaporation_Rate_surface                                        (time, lat, lon) float32 ...
#     Categorical_Rain_surface                                                  (time7, lat, lon) float32 ...
#     Land_cover_0__sea_1__land_surface                                         (time5, lat, lon) float32 ...
#     Ice_cover_surface                                                         (time5, lat, lon) float32 ...
#     Pressure_surface                                                          (time5, lat, lon) float32 ...
#     Specific_humidity_pressure_difference_layer                               (time5, pressure_difference_layer1, lat, lon) float32 ...
#     Temperature_pressure_difference_layer                                     (time5, pressure_difference_layer1, lat, lon) float32 ...
#     Temperature_surface                                                       (time5, lat, lon) float32 ...
#     Visibility_surface                                                        (time7, lat, lon) float32 ...
#     Temperature_depth_below_surface_layer                                     (time8, depth_below_surface_layer, lat, lon) float32 ...
#     Relative_humidity_pressure_difference_layer                               (time5, pressure_difference_layer1, lat, lon) float32 ...
#     Relative_humidity_sigma_layer                                             (time5, sigma_layer, lat, lon) float32 ...
#     u-component_of_wind_pressure_difference_layer                             (time5, pressure_difference_layer1, lat, lon) float32 ...
#     Haines_index_surface                                                      (time3, lat, lon) float32 ...
#     Soil_temperature_depth_below_surface_layer                                (time3, depth_below_surface_layer, lat, lon) float32 ...
#     v-component_of_wind_pressure_difference_layer                             (time5, pressure_difference_layer1, lat, lon) float32 ...
#     Geopotential_height_surface                                               (time5, lat, lon) float32 ...
#     Convective_available_potential_energy_surface                             (time5, lat, lon) float32 ...
#     Convective_available_potential_energy_pressure_difference_layer           (time5, pressure_difference_layer2, lat, lon) float32 ...
#     Convective_inhibition_surface                                             (time5, lat, lon) float32 ...
#     Convective_inhibition_pressure_difference_layer                           (time5, pressure_difference_layer2, lat, lon) float32 ...
#     Precipitation_rate_surface                                                (time7, lat, lon) float32 ...
#     Storm_relative_helicity_height_above_ground_layer                         (time3, height_above_ground_layer1, lat, lon) float32 ...
#     Snow_depth_surface                                                        (time3, lat, lon) float32 ...
#     Water_equivalent_of_accumulated_snow_depth_surface                        (time5, lat, lon) float32 ...
#     Total_cloud_cover_convective_cloud                                        (time8, lat, lon) float32 ...
#     Best_4_layer_Lifted_Index_surface                                         (time5, lat, lon) float32 ...
#     Sunshine_Duration_surface                                                 (time3, lat, lon) float32 ...
#     5-Wave_Geopotential_Height_isobaric                                       (time6, isobaric3, lat, lon) float32 ...
#     Relative_humidity_entire_atmosphere_single_layer                          (time5, lat, lon) float32 ...
#     Relative_humidity_highest_tropospheric_freezing                           (time5, lat, lon) float32 ...
#     Wilting_Point_surface                                                     (time3, lat, lon) float32 ...
#     Categorical_Freezing_Rain_surface                                         (time7, lat, lon) float32 ...
#     Per_cent_frozen_precipitation_surface                                     (time3, lat, lon) float32 ...
#     Temperature_isobaric                                                      (time5, isobaric, lat, lon) float32 ...
#     Relative_humidity_isobaric                                                (time5, isobaric6, lat, lon) float32 ...
#     Relative_humidity_zeroDegC_isotherm                                       (time5, lat, lon) float32 ...
#     Total_cloud_cover_isobaric                                                (time7, isobaric7, lat, lon) float32 ...
#     u-component_of_wind_isobaric                                              (time5, isobaric6, lat, lon) float32 ...
#     v-component_of_wind_isobaric                                              (time5, isobaric6, lat, lon) float32 ...
#     Geopotential_height_isobaric                                              (time5, isobaric, lat, lon) float32 ...
#     Geopotential_height_zeroDegC_isotherm                                     (time5, lat, lon) float32 ...
#     U-Component_Storm_Motion_height_above_ground_layer                        (time3, height_above_ground_layer, lat, lon) float32 ...
#     u-component_of_wind_planetary_boundary                                    (time3, lat, lon) float32 ...
#     Land-sea_coverage_nearest_neighbor_land1sea0_surface                      (time1, lat, lon) float32 ...
#     Categorical_Ice_Pellets_surface                                           (time7, lat, lon) float32 ...
#     Vertical_velocity_pressure_isobaric                                       (time5, isobaric5, lat, lon) float32 ...
#     Geopotential_height_anomaly_isobaric                                      (time4, isobaric1, lat, lon) float32 ...
#     Vertical_velocity_geometric_isobaric                                      (time7, isobaric5, lat, lon) float32 ...
#     Absolute_vorticity_isobaric                                               (time5, isobaric4, lat, lon) float32 ...
#     Pressure_msl                                                              (time, lat, lon) float32 ...
#     Pressure_reduced_to_MSL_msl                                               (time5, lat, lon) float32 ...
#     Cloud_mixing_ratio_isobaric                                               (time5, isobaric7, lat, lon) float32 ...
#     Ice_water_mixing_ratio_isobaric                                           (time7, isobaric7, lat, lon) float32 ...
#     Rain_mixing_ratio_isobaric                                                (time7, isobaric7, lat, lon) float32 ...
#     Snow_mixing_ratio_isobaric                                                (time7, isobaric7, lat, lon) float32 ...
#     Pressure_maximum_wind                                                     (time5, lat, lon) float32 ...
#     Temperature_altitude_above_msl                                            (time5, altitude_above_msl, lat, lon) float32 ...
#     Temperature_maximum_wind                                                  (time5, lat, lon) float32 ...
#     Graupel_snow_pellets_isobaric                                             (time7, isobaric7, lat, lon) float32 ...
#     u-component_of_wind_altitude_above_msl                                    (time5, altitude_above_msl, lat, lon) float32 ...
#     u-component_of_wind_maximum_wind                                          (time5, lat, lon) float32 ...
#     v-component_of_wind_altitude_above_msl                                    (time5, altitude_above_msl, lat, lon) float32 ...
#     v-component_of_wind_maximum_wind                                          (time5, lat, lon) float32 ...
#     ICAO_Standard_Atmosphere_Reference_Height_maximum_wind                    (time3, lat, lon) float32 ...
#     Geopotential_height_maximum_wind                                          (time5, lat, lon) float32 ...
#     Apparent_temperature_height_above_ground                                  (time3, height_above_ground2, lat, lon) float32 ...
#     V-Component_Storm_Motion_height_above_ground_layer                        (time3, height_above_ground_layer, lat, lon) float32 ...
#     Field_Capacity_surface                                                    (time3, lat, lon) float32 ...
#     v-component_of_wind_planetary_boundary                                    (time3, lat, lon) float32 ...
#     Ice_growth_rate_altitude_above_msl                                        (time2, altitude_above_msl1, lat, lon) float32 ...
#     Precipitable_water_entire_atmosphere_single_layer                         (time5, lat, lon) float32 ...
#     Categorical_Snow_surface                                                  (time7, lat, lon) float32 ...
#     Pressure_tropopause                                                       (time5, lat, lon) float32 ...
#     Specific_humidity_height_above_ground                                     (time5, height_above_ground3, lat, lon) float32 ...
#     Temperature_tropopause                                                    (time5, lat, lon) float32 ...
#     Temperature_height_above_ground                                           (time5, height_above_ground4, lat, lon) float32 ...
#     Pressure_height_above_ground                                              (time3, height_above_ground, lat, lon) float32 ...
#     Relative_humidity_height_above_ground                                     (time5, height_above_ground2, lat, lon) float32 ...
#     u-component_of_wind_tropopause                                            (time5, lat, lon) float32 ...
#     u-component_of_wind_height_above_ground                                   (time5, height_above_ground1, lat, lon) float32 ...
#     v-component_of_wind_tropopause                                            (time5, lat, lon) float32 ...
#     v-component_of_wind_height_above_ground                                   (time5, height_above_ground1, lat, lon) float32 ...
#     ICAO_Standard_Atmosphere_Reference_Height_tropopause                      (time3, lat, lon) float32 ...
#     Geopotential_height_tropopause                                            (time5, lat, lon) float32 ...
#     Dewpoint_temperature_height_above_ground                                  (time3, height_above_ground2, lat, lon) float32 ...
#     Temperature_sigma                                                         (time5, sigma, lat, lon) float32 ...
#     Relative_humidity_sigma                                                   (time5, sigma, lat, lon) float32 ...
#     Potential_temperature_sigma                                               (time5, sigma, lat, lon) float32 ...
#     u-component_of_wind_sigma                                                 (time5, sigma, lat, lon) float32 ...
#     v-component_of_wind_sigma                                                 (time5, sigma, lat, lon) float32 ...
#     Planetary_Boundary_Layer_Height_surface                                   (time5, lat, lon) float32 ...
#     Cloud_mixing_ratio_hybrid                                                 (time7, hybrid, lat, lon) float32 ...
#     Ice_water_mixing_ratio_hybrid                                             (time7, hybrid, lat, lon) float32 ...
#     Vertical_velocity_pressure_sigma                                          (time5, sigma, lat, lon) float32 ...
#     Rain_mixing_ratio_hybrid                                                  (time7, hybrid, lat, lon) float32 ...
#     Snow_mixing_ratio_hybrid                                                  (time7, hybrid, lat, lon) float32 ...
#     Composite_reflectivity_entire_atmosphere                                  (time7, lat, lon) float32 ...
#     Geopotential_height_highest_tropospheric_freezing                         (time5, lat, lon) float32 ...
#     5-Wave_Geopotential_Height_Anomaly_isobaric                               (time4, isobaric3, lat, lon) float32 ...
#     Graupel_snow_pellets_hybrid                                               (time7, hybrid, lat, lon) float32 ...
#     Cloud_water_entire_atmosphere_single_layer                                (time5, lat, lon) float32 ...
#     Pressure_potential_vorticity_surface                                      (time5, potential_vorticity_surface, lat, lon) float32 ...
#     Temperature_potential_vorticity_surface                                   (time5, potential_vorticity_surface, lat, lon) float32 ...
#     u-component_of_wind_potential_vorticity_surface                           (time5, potential_vorticity_surface, lat, lon) float32 ...
#     v-component_of_wind_potential_vorticity_surface                           (time5, potential_vorticity_surface, lat, lon) float32 ...
#     Geopotential_height_potential_vorticity_surface                           (time5, potential_vorticity_surface, lat, lon) float32 ...
# Attributes:
#     Originating_or_generating_Center:                                        ...
#     Originating_or_generating_Subcenter:                                     ...
#     GRIB_table_version:                                                      ...
#     Type_of_generating_process:                                              ...
#     Analysis_or_forecast_generating_process_identifier_defined_by_originating...
#     file_format:                                                             ...
#     Conventions:                                                             ...
#     history:                                                                 ...
#     featureType:                                                             ...
#     _CoordSysBuilder:                                                        ...
